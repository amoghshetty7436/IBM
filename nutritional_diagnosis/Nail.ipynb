# %%
import tensorflow as tf
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
# Mount Google Drive to access your dataset if needed
from google.colab import drive
drive.mount('/content/drive')

# Define dataset paths
dataset_path = '/content/drive/MyDrive/Nail Images/train'
test_dataset_path = '/content/drive/MyDrive/Nail Images/test'

# Step 1: Load Datasets using image_dataset_from_directory
batch_size = 8
img_size = (224, 224)

# Load the training and validation datasets
train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    dataset_path,
    image_size=img_size,
    batch_size=batch_size,
    label_mode='categorical',
    validation_split=0.2,
    subset='training',
    seed=42,
)

val_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    dataset_path,
    image_size=img_size,
    batch_size=batch_size,
    label_mode='categorical',
    validation_split=0.2,
    subset='validation',
    seed=42,
)

# Load the test dataset
test_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    test_dataset_path,
    image_size=img_size,
    batch_size=batch_size,
    label_mode='categorical',
)

# Retrieve class names
class_names = train_dataset.class_names
print(f"Class names: {class_names}")

# Step 2: Normalize the datasets
def normalize_img(image, label):
    return tf.cast(image, tf.float32) / 255.0, label

train_dataset = train_dataset.map(normalize_img)
val_dataset = val_dataset.map(normalize_img)
test_dataset = test_dataset.map(normalize_img)

# Step 3: Load Pre-Trained Model (MobileNetV2)
base_model = MobileNetV2(weights="imagenet", include_top=False, input_shape=(224, 224, 3))
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation="relu")(x)  # Reduced size for small dataset
x = Dropout(0.4)(x)  # Add dropout for regularization
predictions = Dense(len(class_names), activation="softmax")(x)

model = Model(inputs=base_model.input, outputs=predictions)

# Freeze the base model layers initially
for layer in base_model.layers:
    layer.trainable = False

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss="categorical_crossentropy", metrics=["accuracy"])

# Step 4: Train the Model
epochs = 64  # Reduced epochs for smaller dataset

history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=epochs,
    verbose=1,
)

# Step 5: Evaluate the Model
loss, accuracy = model.evaluate(test_dataset, verbose=1)
print(f"Test Accuracy: {accuracy * 100:.2f}%")

# Step 6: Save the Model
# Save the model in the SavedModel format
saved_model_path = "/content/drive/MyDrive/nail_disease_saved_model"
model.export(saved_model_path)
print(f"Model saved in SavedModel format at {saved_model_path}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Found 661 files belonging to 17 classes.
# Using 529 files for training.
# Found 661 files belonging to 17 classes.
# Using 132 files for validation.
# Found 183 files belonging to 17 classes.
# Class names: ['Darier_s disease', 'Muehrck-e_s lines', 'aloperia areata', 'beau_s lines', 'bluish nail', 'clubbing', 'eczema', 'half and half nailes (Lindsay_s nails)', 'koilonychia', 'leukonychia', 'onycholycis', 'pale nail', 'red lunula', 'splinter hemmorrage', 'terry_s nail', 'white nail', 'yellow nails']
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 195s 3s/step - accuracy: 0.0976 - loss: 3.0716 - val_accuracy: 0.2500 - val_loss: 2.5717
# Epoch 2/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 16s 56ms/step - accuracy: 0.2235 - loss: 2.4928 - val_accuracy: 0.3485 - val_loss: 2.3208
# Epoch 3/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.3061 - loss: 2.2294 - val_accuracy: 0.3636 - val_loss: 2.1940
# Epoch 4/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.3539 - loss: 1.9969 - val_accuracy: 0.4015 - val_loss: 2.0846
# Epoch 5/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - accuracy: 0.4811 - loss: 1.6782 - val_accuracy: 0.3561 - val_loss: 2.0231
# Epoch 6/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.5143 - loss: 1.5169 - val_accuracy: 0.4545 - val_loss: 1.9202
# Epoch 7/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.5632 - loss: 1.3362 - val_accuracy: 0.4394 - val_loss: 1.8673
# Epoch 8/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - accuracy: 0.6287 - loss: 1.2595 - val_accuracy: 0.4470 - val_loss: 1.7759
# Epoch 9/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.6991 - loss: 1.1029 - val_accuracy: 0.4621 - val_loss: 1.8037
# Epoch 10/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.6917 - loss: 1.0454 - val_accuracy: 0.5152 - val_loss: 1.7580
# Epoch 11/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.7550 - loss: 0.8301 - val_accuracy: 0.4924 - val_loss: 1.6867
# Epoch 12/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.7666 - loss: 0.7971 - val_accuracy: 0.5076 - val_loss: 1.6868
# Epoch 13/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.7389 - loss: 0.8178 - val_accuracy: 0.4924 - val_loss: 1.6651
# Epoch 14/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.8106 - loss: 0.6837 - val_accuracy: 0.5227 - val_loss: 1.6937
# Epoch 15/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.8460 - loss: 0.5929 - val_accuracy: 0.5076 - val_loss: 1.7772
# Epoch 16/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.8226 - loss: 0.6100 - val_accuracy: 0.5000 - val_loss: 1.7421
# Epoch 17/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.8241 - loss: 0.5899 - val_accuracy: 0.5455 - val_loss: 1.6489
# Epoch 18/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.8708 - loss: 0.4618 - val_accuracy: 0.5152 - val_loss: 1.6879
# Epoch 19/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - accuracy: 0.8705 - loss: 0.4646 - val_accuracy: 0.5303 - val_loss: 1.7102
# Epoch 20/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9081 - loss: 0.3832 - val_accuracy: 0.5455 - val_loss: 1.7034
# Epoch 21/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.8766 - loss: 0.4242 - val_accuracy: 0.5076 - val_loss: 1.7904
# Epoch 22/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9077 - loss: 0.3353 - val_accuracy: 0.5303 - val_loss: 1.7512
# Epoch 23/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.9194 - loss: 0.2752 - val_accuracy: 0.5000 - val_loss: 1.7997
# Epoch 24/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9391 - loss: 0.3131 - val_accuracy: 0.5303 - val_loss: 1.8288
# Epoch 25/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9244 - loss: 0.2984 - val_accuracy: 0.5303 - val_loss: 1.8724
# Epoch 26/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.9314 - loss: 0.2994 - val_accuracy: 0.5606 - val_loss: 1.7531
# Epoch 27/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9191 - loss: 0.2952 - val_accuracy: 0.5379 - val_loss: 1.7607
# Epoch 28/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9429 - loss: 0.2154 - val_accuracy: 0.5455 - val_loss: 1.8556
# Epoch 29/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - accuracy: 0.9286 - loss: 0.2500 - val_accuracy: 0.5303 - val_loss: 1.7802
# Epoch 30/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9333 - loss: 0.2823 - val_accuracy: 0.5530 - val_loss: 1.7963
# Epoch 31/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.9412 - loss: 0.2143 - val_accuracy: 0.5530 - val_loss: 1.8657
# Epoch 32/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.9270 - loss: 0.2245 - val_accuracy: 0.5379 - val_loss: 1.8960
# Epoch 33/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9531 - loss: 0.1940 - val_accuracy: 0.5303 - val_loss: 1.9244
# Epoch 34/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9400 - loss: 0.1848 - val_accuracy: 0.5152 - val_loss: 1.9966
# Epoch 35/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.9551 - loss: 0.1909 - val_accuracy: 0.5379 - val_loss: 1.9930
# Epoch 36/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.9405 - loss: 0.2084 - val_accuracy: 0.5303 - val_loss: 1.9570
# Epoch 37/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9614 - loss: 0.1569 - val_accuracy: 0.5227 - val_loss: 1.9160
# Epoch 38/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9691 - loss: 0.1283 - val_accuracy: 0.5303 - val_loss: 2.0597
# Epoch 39/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - accuracy: 0.9667 - loss: 0.1649 - val_accuracy: 0.5606 - val_loss: 1.9294
# Epoch 40/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.9314 - loss: 0.2321 - val_accuracy: 0.5606 - val_loss: 1.9249
# Epoch 41/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9578 - loss: 0.1729 - val_accuracy: 0.5152 - val_loss: 1.9884
# Epoch 42/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9568 - loss: 0.1699 - val_accuracy: 0.5303 - val_loss: 2.1194
# Epoch 43/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - accuracy: 0.9523 - loss: 0.1862 - val_accuracy: 0.5455 - val_loss: 2.0394
# Epoch 44/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.9737 - loss: 0.1297 - val_accuracy: 0.5379 - val_loss: 2.0690
# Epoch 45/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9597 - loss: 0.1356 - val_accuracy: 0.5379 - val_loss: 2.0572
# Epoch 46/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9772 - loss: 0.1001 - val_accuracy: 0.5758 - val_loss: 2.1079
# Epoch 47/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9715 - loss: 0.1083 - val_accuracy: 0.5530 - val_loss: 2.1158
# Epoch 48/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - accuracy: 0.9761 - loss: 0.1143 - val_accuracy: 0.5227 - val_loss: 2.1795
# Epoch 49/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.9942 - loss: 0.0677 - val_accuracy: 0.5379 - val_loss: 2.0999
# Epoch 50/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9672 - loss: 0.1073 - val_accuracy: 0.5227 - val_loss: 2.2026
# Epoch 51/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - accuracy: 0.9876 - loss: 0.0687 - val_accuracy: 0.4621 - val_loss: 2.2959
# Epoch 52/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.9822 - loss: 0.1101 - val_accuracy: 0.5530 - val_loss: 2.0093
# Epoch 53/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9690 - loss: 0.1255 - val_accuracy: 0.5076 - val_loss: 2.2101
# Epoch 54/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9665 - loss: 0.1197 - val_accuracy: 0.5152 - val_loss: 2.2445
# Epoch 55/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9629 - loss: 0.0909 - val_accuracy: 0.5227 - val_loss: 2.1800
# Epoch 56/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9936 - loss: 0.0679 - val_accuracy: 0.5076 - val_loss: 2.2306
# Epoch 57/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9626 - loss: 0.1130 - val_accuracy: 0.5455 - val_loss: 2.1942
# Epoch 58/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - accuracy: 0.9741 - loss: 0.0840 - val_accuracy: 0.5000 - val_loss: 2.3599
# Epoch 59/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9840 - loss: 0.0675 - val_accuracy: 0.5076 - val_loss: 2.2322
# Epoch 60/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9695 - loss: 0.0729 - val_accuracy: 0.5379 - val_loss: 2.2474
# Epoch 61/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - accuracy: 0.9796 - loss: 0.0914 - val_accuracy: 0.5530 - val_loss: 2.3700
# Epoch 62/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9605 - loss: 0.1199 - val_accuracy: 0.4773 - val_loss: 2.3453
# Epoch 63/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9776 - loss: 0.1144 - val_accuracy: 0.5000 - val_loss: 2.3171
# Epoch 64/64
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9921 - loss: 0.0577 - val_accuracy: 0.5152 - val_loss: 2.3778
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.7907 - loss: 1.0384
# Test Accuracy: 83.61%
# Saved artifact at '/content/drive/MyDrive/nail_disease_saved_model'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 17), dtype=tf.float32, name=None)
# Captures:
#   137867608475984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867608478480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867608477520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867608478864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867608479056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867608478288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867608476368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867608478096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867608479248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867608479824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867608480784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867608480400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867608480592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867608481552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867608481168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867608483664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867608484432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867608483472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867608485392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867608485008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867608486160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867608487120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867608484624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867608485776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867608486928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867608488464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867608489808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867608489616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867608489424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867608487312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587060560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587061520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587061712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587061328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587059984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587062096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587063440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587063632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587063248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587062480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587060944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587065552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587065744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587065360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587059792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587064400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587067664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587067856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587067472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587064976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587068240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587069584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587069776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587069392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587068624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587070160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587071504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587071696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587071312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587070544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587072080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587073424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587073616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587073232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587072464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587074000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587075344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587075536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587075152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587074384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587072848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587405008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587403856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587404816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587405200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587405584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587406928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587407120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587406736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587405968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587407504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587408848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587409040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587408656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587407888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587409424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587410768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587410960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587410576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587409808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587411344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587412688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587412880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587412496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587411728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587413264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587414608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587414800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587414416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587413648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587415184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587416528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587416720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587416336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587415568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587417104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587418448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587418640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587418256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587417488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587419024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587419408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587814032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587404432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587417872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587814224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587815568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587815760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587815376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587814608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587816144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587817488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587817680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587817296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587816528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587818064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587819408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587819600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587819216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587818448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587819984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587821328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587821520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587821136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587820368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587821904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587823248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587823440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587823056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587822288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587823824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587825168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587825360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587824976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587824208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587825744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587827088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587827280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587826896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587826128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587827664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587829008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587829200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587828816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587828048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867587826512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578540880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578540112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578541072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578540304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578541840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578543184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578543376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578542992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578542224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578543760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578545104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578545296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578544912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578544144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578545680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578547024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578547216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578546832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578546064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578547600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578548944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578549136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578548752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578547984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578549520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578550864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578551056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578550672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578549904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578551440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578552784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578552976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578552592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578551824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578553360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578554704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578554896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578554512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578553744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578555280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578555664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578933904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578552400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578554128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578934096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578935440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578935632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578935248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578934480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578936016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578937360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578937552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578937168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578936400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578937936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578939280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578939472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578939088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578938320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578939856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578941200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578941392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578941008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578940240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578941776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578943120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578943312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578942928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578942160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578943696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578945040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578945232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578944848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578944080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578945616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578946960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578947152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578946768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578946000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578947536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578948880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578949072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578948688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578947920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867578946384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867358766288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867358765136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867358766096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867358766480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867358766864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867358768208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867358768400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867358768016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867358767248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867358768784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867358770128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867358770320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867358769936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867358769168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867358770704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867358772048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867358772240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867358771856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867358771088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867358765712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867358774544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867358773776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137867358775888: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Model saved in SavedModel format at /content/drive/MyDrive/nail_disease_saved_model
